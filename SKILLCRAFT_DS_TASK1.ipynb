# %% [markdown]
# ______________
# <center>
#   <h1 style="font-size: 40px; font-weight: bold">SKILLCRAFT TECHNOLOGY INTERNSHIP</h1>
# </center>
#
# ______

# %% [markdown]
# <center>
#   <h1 style="font-size: 30px; font-weight: bold">TASK 1: CREATE BAR PLOT / HISTOGRAM</h1>
# </center>
#
#
# * **Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.**

# %% [markdown]
# **Intern: Aswathy S**
#
# **Track: Data Science**
#
# **Task Code: SCT_DS_01**
# _________

# %% [markdown]
# ___________
# # **LOADING LIBRARIES**
# _______

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ___________
# # **LOADING LIBRARIES**
# _______

# %%
df = pd.read_csv(r"C:\Users\admin\Downloads\StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
print("Missing values in each column:\n")
print(df.isnull().sum())
# Out:
# Missing values in each column:
#
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
print("Duplicate values:")
print(df.duplicated().sum())
# Out:
# Duplicate values:
# 0

# %%
df['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
df['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
df['lunch'].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
df['test preparation course'].unique()
# Out:
# array(['none', 'completed'], dtype=object)

# %%
df['math score'].unique()
# Out:
# array([ 72,  69,  90,  47,  76,  71,  88,  40,  64,  38,  58,  65,  78,
#         50,  18,  46,  54,  66,  44,  74,  73,  67,  70,  62,  63,  56,
#         97,  81,  75,  57,  55,  53,  59,  82,  77,  33,  52,   0,  79,
#         39,  45,  60,  61,  41,  49,  30,  80,  42,  27,  43,  68,  85,
#         98,  87,  51,  99,  84,  91,  83,  89,  22, 100,  96,  94,  48,
#         35,  34,  86,  92,  37,  28,  24,  26,  95,  36,  29,  32,  93,
#         19,  23,   8], dtype=int64)

# %%
df['reading score'].unique()
# Out:
# array([ 72,  90,  95,  57,  78,  83,  43,  64,  60,  54,  52,  81,  53,
#         75,  89,  32,  42,  58,  69,  73,  71,  74,  70,  65,  87,  56,
#         61,  84,  55,  44,  41,  85,  59,  17,  39,  80,  37,  63,  51,
#         49,  26,  68,  45,  47,  86,  34,  79,  66,  67,  91, 100,  76,
#         77,  82,  92,  93,  62,  88,  50,  28,  48,  46,  23,  38,  94,
#         97,  99,  31,  96,  24,  29,  40], dtype=int64)

# %%
df['writing score'].unique()
# Out:
# array([ 74,  88,  93,  44,  75,  78,  92,  39,  67,  50,  52,  43,  73,
#         70,  58,  86,  28,  46,  61,  63,  53,  80,  72,  55,  65,  38,
#         82,  79,  83,  59,  57,  54,  68,  66,  62,  76,  48,  42,  87,
#         49,  10,  34,  71,  37,  56,  41,  22,  81,  45,  36,  89,  47,
#         90, 100,  64,  98,  51,  40,  84,  69,  33,  60,  85,  91,  77,
#         27,  94,  95,  19,  35,  32,  96,  97,  99,  15,  30,  23],
#       dtype=int64)

# %% [markdown]
# ____________
# # **BAR PLOT AND HISTOGRAMS**
# _________

# %%
# Bar chart for gender distribution
gender_counts = df['gender'].value_counts()

# %%
plt.figure(figsize=(6,4))
gender_counts.plot(kind='bar', color=['red','green'])
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Separate math scores by gender
male_scores = df[df['gender'] == 'male']['math score']
female_scores = df[df['gender'] == 'female']['math score']

# %%
# Plot overlay histograms
plt.figure(figsize=(8,5))
plt.hist(male_scores, bins=10, alpha=0.5, label='Male', color='purple', edgecolor='black')
plt.hist(female_scores, bins=10, alpha=0.5, label='Female', color='pink', edgecolor='black')

plt.title('Math Score Distribution by Gender')
plt.xlabel('Math Score')
plt.ylabel('Number of Students')
plt.legend()
plt.tight_layout()
plt.show()

# %%
df['parental level of education'].value_counts().plot(
    kind='bar', figsize=(8,4), color='teal', edgecolor='black'
)
plt.title('Parental Level of Education Distribution')
plt.xlabel('Education Level')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df['race/ethnicity'].value_counts().plot(
    kind='bar', figsize=(8,4), color='blue', edgecolor='black'
)
plt.title('race/Ethnicity Distribution')
plt.xlabel('Race/Ethnicity')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# --- 2. Test preparation course completion counts ---
plt.figure(figsize=(6,4))
df['test preparation course'].value_counts().plot(
    kind='bar', color=['mediumseagreen','orange'], edgecolor='black'
)
plt.title('Test Preparation Course Completion Counts')
plt.xlabel('Test Preparation Course')
plt.ylabel('Number of Students')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# --- 3. Lunch type distribution ---
plt.figure(figsize=(6,4))
df['lunch'].value_counts().plot(
    kind='bar', color=['orchid','gold'], edgecolor='black'
)
plt.title('Lunch Type Distribution')
plt.xlabel('Lunch Type')
plt.ylabel('Number of Students')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Example: Histogram for math score
plt.figure(figsize=(6,4))
plt.hist(df['math score'], bins=10, color='orange', edgecolor='black')
plt.title('Distribution of Math Scores')
plt.xlabel('Math Score')
plt.ylabel('Number of Students')
plt.tight_layout()
plt.show()

# %%
avg_math_by_gender = df.groupby('gender')['math score'].mean()

plt.figure(figsize=(6,4))
avg_math_by_gender.plot(kind='bar', color=['skyblue','lightcoral'], edgecolor='black')
plt.title('Average Math Score by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Math Score')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['reading score'], bins=10, color='red', edgecolor='black')
plt.title('Distribution of Reading Scores')
plt.xlabel('Reading Score')
plt.ylabel('Number of Students')
plt.tight_layout()
plt.show()

# %%
avg_reading_by_gender = df.groupby('gender')['reading score'].mean()

plt.figure(figsize=(6,4))
avg_math_by_gender.plot(kind='bar', color=['skyblue','lightcoral'], edgecolor='black')
plt.title('Average Reading Score by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Reading Score')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['writing score'], bins=10, color='yellow', edgecolor='black')
plt.title('Distribution of Writing Scores')
plt.xlabel('Writing Score')
plt.ylabel('Number of Students')
plt.tight_layout()
plt.show()

# %%
avg_reading_by_gender = df.groupby('gender')['writing score'].mean()

plt.figure(figsize=(6,4))
avg_math_by_gender.plot(kind='bar', color=['skyblue','lightcoral'], edgecolor='black')
plt.title('Average Writing Score by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Writing Score')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ------------------------------------------------------------END----------------------------------------------------------------
